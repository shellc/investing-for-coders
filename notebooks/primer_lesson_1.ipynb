# %%
import os, sys, math, warnings
warnings.filterwarnings('ignore')

from datetime import datetime, timedelta

import pandas as pd
import numpy as np

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

pd.set_option('display.float_format', lambda x: '%.4f' % x)

# %%
yeb = pd.read_csv("../data/yeb.csv")
treasury_rates = pd.read_csv("../data/treasury_rates.csv")
shibor_3m = pd.read_csv("../data/shibor_3m.csv")

data_to_plot = yeb.set_index('Date').rename(columns={'Rate': 'YEB'})
data_to_plot['CN_TY2'] = treasury_rates.set_index('date')['cn_2y']
data_to_plot['SHIBOR_3M'] = shibor_3m.set_index('Date')['Rate']

# %%
data_to_plot.plot.line(figsize=(10,5))
# Out:
# <Axes: xlabel='Date'>
